# %% [markdown]
# # Part 9: Доведем модель на базе Xception до максимальных показателей.
# - Применим оптимальные полученные комбинации аугментации, batch и dropout нормализации.
# - Применим оптимальные полученные комбинации аугментации.
# - Применим файн тюнинг.
# - Уменьшим степень аугментации в конце обучения.
# - Добавим Test Time Augmentation (TTA).

# %% [markdown]
# ## Библиотеки

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import zipfile
import csv
import sys
import os


import tensorflow as tf

config = tf.compat.v1.ConfigProto(
    gpu_options=tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers import *
from ImageDataAugmentor.image_data_augmentor import *
import albumentations

from sklearn.model_selection import train_test_split, StratifiedKFold

import PIL
from PIL import ImageOps, ImageFilter
# увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
# графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

print('Python       :', sys.version.split('\n')[0])
print('Numpy        :', np.__version__)
print('Tensorflow   :', tf.__version__)
print('Keras        :', tf.keras.__version__)
# Out:
# Python       : 3.8.5 (tags/v3.8.5:580fbb0, Jul 20 2020, 15:57:54) [MSC v.1924 64 bit (AMD64)]
# Numpy        : 1.19.4
# Tensorflow   : 2.4.0
# Keras        : 2.4.0

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip freeze > requirements.txt

# %% [markdown]
# ## Основные настройки

# %%
# В setup выносим основные настройки: так удобнее их перебирать в дальнейшем.

EPOCHS = 10  # эпох на обучение
BATCH_SIZE = 16  # уменьшаем batch если сеть большая, иначе не влезет в память на GPU
LR = 0.001 # lerning rate
VAL_SPLIT = 0.15  # сколько данных выделяем на тест = 15%

CLASS_NUM = 10  # количество классов в нашей задаче
IMG_SIZE = 224  # какого размера подаем изображения в сеть
IMG_CHANNELS = 3   # у RGB 3 канала
input_shape = (IMG_SIZE, IMG_SIZE, IMG_CHANNELS)

part = 'part_9'  # Версия эксперимента

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
PYTHONHASHSEED = 0

# %%
# Графики
def make_graf(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'b', label='Training acc')
  plt.plot(epochs, val_acc, 'r', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %% [markdown]
# ## EDA / Анализ данных

# %%
train_df = pd.read_csv("data/train.csv")
sample_submission = pd.read_csv("data/sample-submission.csv")
train_df.head()
# Out:
#            Id  Category
# 0  100155.jpg         0
# 1  100306.jpg         0
# 2  100379.jpg         0
# 3  100380.jpg         0
# 4  100389.jpg         0

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15561 entries, 0 to 15560
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        15561 non-null  object
#  1   Category  15561 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 243.3+ KB

# %%
train_df.Category.value_counts()
# Out:
# 1    1971
# 8    1765
# 6    1733
# 5    1631
# 0    1613
# 3    1528
# 2    1458
# 4    1400
# 9    1255
# 7    1207
# Name: Category, dtype: int64

# %% [markdown]
# Распределение классов достаточно равномерное — это хорошо.

# %%
# print('Распаковываем картинки')
# # Will unzip the files so that you can see them..
# for data_zip in ['train.zip', 'test.zip']:
#     with zipfile.ZipFile("data/"+data_zip, "r") as z:
#         z.extractall('data/')

# print(os.listdir('data/'))

# %% [markdown]
# Посмотрим на примеры картинок и их размеры чтоб понимать как их лучше обработать и сжимать.

# %%
print('Пример картинок (random sample)')
plt.figure(figsize=(12, 8))

random_image = train_df.sample(n=9)
random_image_paths = random_image['Id'].values
random_image_cat = random_image['Category'].values

for index, path in enumerate(random_image_paths):
    im = PIL.Image.open(f'data/train/{random_image_cat[index]}/{path}')
    plt.subplot(3, 3, index+1)
    plt.imshow(im)
    plt.title('Class: '+str(random_image_cat[index]))
    plt.axis('off')

plt.show()
# Out:
# Пример картинок (random sample)

# %%
image = PIL.Image.open('data/train/0/100380.jpg')
imgplot = plt.imshow(image)
plt.show()
image.size
# Out:
# (640, 480)

# %% [markdown]
# ## Подготовка данных
# ### Аугментация данных

# %%
AUGMENTATIONS = albumentations.Compose([
    albumentations.HorizontalFlip(p=0.5),
    albumentations.Rotate(limit=10, interpolation=1, border_mode=4,
                          value=None, mask_value=None, always_apply=False, p=0.8),
    albumentations.OneOf([
        albumentations.RandomBrightnessContrast(
            brightness_limit=0.3, contrast_limit=0.3),
        albumentations.RandomBrightnessContrast(
            brightness_limit=0.2, contrast_limit=0.2),
        albumentations.RandomBrightnessContrast(
            brightness_limit=0.1, contrast_limit=0.1)
    ], p=0.7),
    albumentations.Blur(blur_limit=3, always_apply=False, p=0.5),
    albumentations.HueSaturationValue(
        hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, always_apply=False, p=0.7),
    albumentations.RGBShift(r_shift_limit=20, g_shift_limit=20,
                            b_shift_limit=20, always_apply=False, p=0.7),
    albumentations.FancyPCA(alpha=0.1, always_apply=False, p=0.5),
    albumentations.ChannelShuffle(p=0.7),
    albumentations.CLAHE(clip_limit=3.0, tile_grid_size=(
        8, 8), always_apply=False, p=0.3),
    albumentations.Resize(IMG_SIZE, IMG_SIZE)
])

train_datagen = ImageDataAugmentor(
    rescale=1./255,
    augment=AUGMENTATIONS,
    validation_split=VAL_SPLIT,
)

test_datagen = ImageDataAugmentor(rescale=1. / 255)

# %% [markdown]
# ### Генерация данных

# %%
# Завернем наши данные в генератор:
train_generator = train_datagen.flow_from_directory(
    'data/train/',      # директория где расположены папки с картинками
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, seed=RANDOM_SEED,
    subset='training')  # set as training data

test_generator = train_datagen.flow_from_directory(
    'data/train/',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, seed=RANDOM_SEED,
    subset='validation')  # set as validation data

test_sub_generator = test_datagen.flow_from_dataframe(
    dataframe=sample_submission,
    directory='data/test_upload/',
    x_col="Id",
    y_col=None,
    shuffle=False,
    class_mode=None,
    seed=RANDOM_SEED,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE)
# Out:
# Found 13232 images belonging to 10 classes.
# Found 2329 images belonging to 10 classes.
# Found 6675 validated image filenames.

# %% [markdown]
# Посмотрим результат

# %%
from skimage import io
 
def imshow(image_RGB):
  io.imshow(image_RGB)
  io.show()
 
x,y = train_generator.next()
print('Пример картинок из train_generator')
plt.figure(figsize=(12,12))
 
for i in range(0,9):
    image = x[i]
    plt.subplot(3,3, i+1)
    plt.imshow(image)
    #plt.title('Class: '+str(y[i]))
    #plt.axis('off')
plt.show()
# Out:
# Пример картинок из train_generator

# %% [markdown]
# ## Построение модели
# ### Загружаем предобученную сеть Xception

# %%
base_model = Xception(weights='imagenet',
                      include_top=False, input_shape=input_shape)

# %% [markdown]
# Замораживаем веса

# %%
# first: train only the top layers (which were randomly initialized)
base_model.trainable = False

# %% [markdown]
# Строим модель

# %%
# Устанавливаем новую "голову" (head)
x = base_model.output

# x = BatchNormalization()(x)
# x = Dropout(0.2)(x)

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(256, activation='relu')(x)

# x = BatchNormalization()(x)
x = Dropout(0.25)(x)

# and a logistic layer -- let's say we have 10 classes
predictions = Dense(CLASS_NUM, activation='softmax')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(loss="categorical_crossentropy",
              optimizer=optimizers.Adam(lr=LR), metrics=["accuracy"])

# %% [markdown]
# ## Обучение модели
# Добавим ModelCheckpoint чтоб сохранять прогресс обучения модели и можно было потом подгрузить и дообучить модель.

# %%
checkpoint = ModelCheckpoint('best_model_{}.hdf5'.format(
    part), monitor=['val_accuracy'], verbose=1, mode='max')
earlystop = EarlyStopping(monitor='val_accuracy',
                          patience=5, restore_best_weights=True)
callbacks_list = [checkpoint, earlystop]

# %% [markdown]
# ### Обучаем

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=len(train_generator),
    validation_data=test_generator,
    validation_steps=len(test_generator),
    epochs=EPOCHS,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/10
# 827/827 [==============================] - 303s 355ms/step - loss: 1.7347 - accuracy: 0.3673 - val_loss: 1.2754 - val_accuracy: 0.5333
#
# Epoch 00001: saving model to best_model_part_9.hdf5
# Epoch 2/10
# 827/827 [==============================] - 232s 280ms/step - loss: 1.3154 - accuracy: 0.5244 - val_loss: 1.2106 - val_accuracy: 0.5573
#
# Epoch 00002: saving model to best_model_part_9.hdf5
# Epoch 3/10
# 827/827 [==============================] - 220s 266ms/step - loss: 1.2352 - accuracy: 0.5533 - val_loss: 1.1621 - val_accuracy: 0.5685
#
# Epoch 00003: saving model to best_model_part_9.hdf5
# Epoch 4/10
# 827/827 [==============================] - 217s 263ms/step - loss: 1.1624 - accuracy: 0.5784 - val_loss: 1.1904 - val_accuracy: 0.5513
#
# Epoch 00004: saving model to best_model_part_9.hdf5
# Epoch 5/10
# 827/827 [==============================] - 222s 269ms/step - loss: 1.1268 - accuracy: 0.5949 - val_loss: 1.0984 - val_accuracy: 0.6037
#
# Epoch 00005: saving model to best_model_part_9.hdf5
# Epoch 6/10
# 827/827 [==============================] - 225s 272ms/step - loss: 1.0833 - accuracy: 0.5955 - val_loss: 1.1600 - val_accuracy: 0.5835
#
# Epoch 00006: saving model to best_model_part_9.hdf5
# Epoch 7/10
# 827/827 [==============================] - 221s 267ms/step - loss: 1.0671 - accuracy: 0.6074 - val_loss: 1.0775 - val_accuracy: 0.6058
#
# Epoch 00007: saving model to best_model_part_9.hdf5
# Epoch 8/10
# 827/827 [==============================] - 244s 294ms/step - loss: 1.0481 - accuracy: 0.6242 - val_loss: 1.0468 - val_accuracy: 0.6196
#
# Epoch 00008: saving model to best_model_part_9.hdf5
# Epoch 9/10
# 827/827 [==============================] - 228s 276ms/step - loss: 1.0337 - accuracy: 0.6218 - val_loss: 1.0781 - val_accuracy: 0.6093
#
# Epoch 00009: saving model to best_model_part_9.hdf5
# Epoch 10/10
# 827/827 [==============================] - 225s 272ms/step - loss: 1.0062 - accuracy: 0.6308 - val_loss: 1.0335 - val_accuracy: 0.6179
#
# Epoch 00010: saving model to best_model_part_9.hdf5

# %%
# сохраним итоговую сеть и подгрузим лучшую итерацию в обучении (best_model)
model.save('model_last_{}.hdf5'.format(part))
model.load_weights('best_model_{}.hdf5'.format(part))

# %%
# Графики
make_graf(history)

# %% [markdown]
# Посмотрим сколько слоев в имиджнет модели

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  132

# %% [markdown]
# Размораживаем имиджнет-модель частично (44 слоя размораживаем, 88 оставляем замороженными)

# %%
base_model.trainable = True

# Fine-tune from this layer onwards
fine_tune_at = 88

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# %% [markdown]
# Уменьшаем learning rate

# %%
LR=0.0005
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adam(lr=LR), metrics=["accuracy"])

# %% [markdown]
# Увеличиваем колиечество эпох обучения, т. к. уменьшили learnig rate

# %%
EPOCHS = 15
history = model.fit_generator(
    train_generator,
    steps_per_epoch=len(train_generator),
    validation_data=test_generator,
    validation_steps=len(test_generator),
    epochs=EPOCHS,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/15
# 827/827 [==============================] - 266s 316ms/step - loss: 1.0294 - accuracy: 0.6435 - val_loss: 0.5157 - val_accuracy: 0.8128
#
# Epoch 00001: saving model to best_model_part_9.hdf5
# Epoch 2/15
# 827/827 [==============================] - 263s 318ms/step - loss: 0.4551 - accuracy: 0.8418 - val_loss: 0.5003 - val_accuracy: 0.8351
#
# Epoch 00002: saving model to best_model_part_9.hdf5
# Epoch 3/15
# 827/827 [==============================] - 262s 317ms/step - loss: 0.3413 - accuracy: 0.8797 - val_loss: 0.5133 - val_accuracy: 0.8446
#
# Epoch 00003: saving model to best_model_part_9.hdf5
# Epoch 4/15
# 827/827 [==============================] - 284s 344ms/step - loss: 0.2847 - accuracy: 0.8969 - val_loss: 0.3324 - val_accuracy: 0.8854
#
# Epoch 00004: saving model to best_model_part_9.hdf5
# Epoch 5/15
# 827/827 [==============================] - 276s 334ms/step - loss: 0.2335 - accuracy: 0.9163 - val_loss: 0.3117 - val_accuracy: 0.8914
#
# Epoch 00005: saving model to best_model_part_9.hdf5
# Epoch 6/15
# 827/827 [==============================] - 272s 329ms/step - loss: 0.2042 - accuracy: 0.9272 - val_loss: 0.3005 - val_accuracy: 0.9025
#
# Epoch 00006: saving model to best_model_part_9.hdf5
# Epoch 7/15
# 827/827 [==============================] - 264s 319ms/step - loss: 0.1828 - accuracy: 0.9315 - val_loss: 0.2736 - val_accuracy: 0.9043
#
# Epoch 00007: saving model to best_model_part_9.hdf5
# Epoch 8/15
# 827/827 [==============================] - 257s 311ms/step - loss: 0.1714 - accuracy: 0.9390 - val_loss: 0.3040 - val_accuracy: 0.9030
#
# Epoch 00008: saving model to best_model_part_9.hdf5
# Epoch 9/15
# 827/827 [==============================] - 261s 315ms/step - loss: 0.1632 - accuracy: 0.9429 - val_loss: 0.2820 - val_accuracy: 0.9154
#
# Epoch 00009: saving model to best_model_part_9.hdf5
# Epoch 10/15
# 827/827 [==============================] - 279s 337ms/step - loss: 0.1484 - accuracy: 0.9431 - val_loss: 0.3205 - val_accuracy: 0.9017
#
# Epoch 00010: saving model to best_model_part_9.hdf5
# Epoch 11/15
# 827/827 [==============================] - 274s 331ms/step - loss: 0.1232 - accuracy: 0.9565 - val_loss: 0.4104 - val_accuracy: 0.8815
#
# Epoch 00011: saving model to best_model_part_9.hdf5
# Epoch 12/15
# 827/827 [==============================] - 278s 336ms/step - loss: 0.1410 - accuracy: 0.9510 - val_loss: 0.2935 - val_accuracy: 0.9154
#
# Epoch 00012: saving model to best_model_part_9.hdf5
# Epoch 13/15
# 827/827 [==============================] - 265s 320ms/step - loss: 0.1273 - accuracy: 0.9585 - val_loss: 0.2728 - val_accuracy: 0.9167
#
# Epoch 00013: saving model to best_model_part_9.hdf5
# Epoch 14/15
# 827/827 [==============================] - 245s 296ms/step - loss: 0.1114 - accuracy: 0.9602 - val_loss: 0.3635 - val_accuracy: 0.8931
#
# Epoch 00014: saving model to best_model_part_9.hdf5
# Epoch 15/15
# 827/827 [==============================] - 256s 309ms/step - loss: 0.1031 - accuracy: 0.9655 - val_loss: 0.2909 - val_accuracy: 0.9094
#
# Epoch 00015: saving model to best_model_part_9.hdf5

# %%
# сохраним итоговую сеть и подгрузим лучшую итерацию в обучении (best_model)
model.save('model_last_{}.hdf5'.format(part))
model.load_weights('best_model_{}.hdf5'.format(part))

# %%
# Графики
make_graf(history)

# %% [markdown]
# Еще размораживаем имиджнет-модель частично (44 слоя размораживаем, 44 оставляем замороженными)

# %%
base_model.trainable = True

# Fine-tune from this layer onwards
fine_tune_at = 44

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# %% [markdown]
# Еще уменьшаем learning rate

# %%
LR=0.0001
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adam(lr=LR), metrics=["accuracy"])

# %% [markdown]
# Еще увеличиваем колиечество эпох обучения

# %%
EPOCHS = 20
history = model.fit_generator(
    train_generator,
    steps_per_epoch=len(train_generator),
    validation_data=test_generator,
    validation_steps=len(test_generator),
    epochs=EPOCHS,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/20
# 827/827 [==============================] - 338s 402ms/step - loss: 0.1026 - accuracy: 0.9650 - val_loss: 0.2450 - val_accuracy: 0.9253
#
# Epoch 00001: saving model to best_model_part_9.hdf5
# Epoch 2/20
# 827/827 [==============================] - 336s 406ms/step - loss: 0.0581 - accuracy: 0.9788 - val_loss: 0.2756 - val_accuracy: 0.9279
#
# Epoch 00002: saving model to best_model_part_9.hdf5
# Epoch 3/20
# 827/827 [==============================] - 379s 458ms/step - loss: 0.0539 - accuracy: 0.9807 - val_loss: 0.2607 - val_accuracy: 0.9292
#
# Epoch 00003: saving model to best_model_part_9.hdf5
# Epoch 4/20
# 827/827 [==============================] - 356s 431ms/step - loss: 0.0382 - accuracy: 0.9878 - val_loss: 0.2525 - val_accuracy: 0.9347
#
# Epoch 00004: saving model to best_model_part_9.hdf5
# Epoch 5/20
# 827/827 [==============================] - 346s 418ms/step - loss: 0.0341 - accuracy: 0.9893 - val_loss: 0.2546 - val_accuracy: 0.9334
#
# Epoch 00005: saving model to best_model_part_9.hdf5
# Epoch 6/20
# 827/827 [==============================] - 345s 417ms/step - loss: 0.0317 - accuracy: 0.9894 - val_loss: 0.2514 - val_accuracy: 0.9292
#
# Epoch 00006: saving model to best_model_part_9.hdf5
# Epoch 7/20
# 827/827 [==============================] - 345s 418ms/step - loss: 0.0291 - accuracy: 0.9910 - val_loss: 0.2839 - val_accuracy: 0.9279
#
# Epoch 00007: saving model to best_model_part_9.hdf5
# Epoch 8/20
# 827/827 [==============================] - 343s 415ms/step - loss: 0.0304 - accuracy: 0.9896 - val_loss: 0.2650 - val_accuracy: 0.9360
#
# Epoch 00008: saving model to best_model_part_9.hdf5
# Epoch 9/20
# 827/827 [==============================] - 347s 420ms/step - loss: 0.0255 - accuracy: 0.9914 - val_loss: 0.2316 - val_accuracy: 0.9420
#
# Epoch 00009: saving model to best_model_part_9.hdf5
# Epoch 10/20
# 827/827 [==============================] - 332s 401ms/step - loss: 0.0283 - accuracy: 0.9907 - val_loss: 0.2629 - val_accuracy: 0.9334
#
# Epoch 00010: saving model to best_model_part_9.hdf5
# Epoch 11/20
# 827/827 [==============================] - 347s 420ms/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.2317 - val_accuracy: 0.9446
#
# Epoch 00011: saving model to best_model_part_9.hdf5
# Epoch 12/20
# 827/827 [==============================] - 336s 406ms/step - loss: 0.0209 - accuracy: 0.9925 - val_loss: 0.2556 - val_accuracy: 0.9330
#
# Epoch 00012: saving model to best_model_part_9.hdf5
# Epoch 13/20
# 827/827 [==============================] - 322s 389ms/step - loss: 0.0249 - accuracy: 0.9924 - val_loss: 0.2441 - val_accuracy: 0.9395
#
# Epoch 00013: saving model to best_model_part_9.hdf5
# Epoch 14/20
# 827/827 [==============================] - 315s 381ms/step - loss: 0.0213 - accuracy: 0.9931 - val_loss: 0.2624 - val_accuracy: 0.9356
#
# Epoch 00014: saving model to best_model_part_9.hdf5
# Epoch 15/20
# 827/827 [==============================] - 317s 383ms/step - loss: 0.0194 - accuracy: 0.9931 - val_loss: 0.2713 - val_accuracy: 0.9395
#
# Epoch 00015: saving model to best_model_part_9.hdf5
# Epoch 16/20
# 827/827 [==============================] - 322s 389ms/step - loss: 0.0239 - accuracy: 0.9928 - val_loss: 0.2564 - val_accuracy: 0.9395
#
# Epoch 00016: saving model to best_model_part_9.hdf5

# %%
# сохраним итоговую сеть и подгрузим лучшую итерацию в обучении (best_model)
model.save('model_last_{}.hdf5'.format(part))
model.load_weights('best_model_{}.hdf5'.format(part))

# %% [markdown]
# Окончательно размораживаем имиджнет-модель

# %%
base_model.trainable = True

# %% [markdown]
# Еще уменьшаем learning rate

# %%
LR=0.00001
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adam(lr=LR), metrics=["accuracy"])

# %% [markdown]
# Еще увеличиваем колиечество эпох обучения

# %%
EPOCHS = 25
history = model.fit_generator(
    train_generator,
    steps_per_epoch=len(train_generator),
    validation_data=test_generator,
    validation_steps=len(test_generator),
    epochs=EPOCHS,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/25
# 827/827 [==============================] - 523s 624ms/step - loss: 0.0282 - accuracy: 0.9910 - val_loss: 0.2364 - val_accuracy: 0.9429
#
# Epoch 00001: saving model to best_model_part_9.hdf5
# Epoch 2/25
# 827/827 [==============================] - 550s 665ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.2282 - val_accuracy: 0.9480
#
# Epoch 00002: saving model to best_model_part_9.hdf5
# Epoch 3/25
# 827/827 [==============================] - 548s 663ms/step - loss: 0.0160 - accuracy: 0.9952 - val_loss: 0.2570 - val_accuracy: 0.9455
#
# Epoch 00003: saving model to best_model_part_9.hdf5
# Epoch 4/25
# 827/827 [==============================] - 537s 649ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.2452 - val_accuracy: 0.9463
#
# Epoch 00004: saving model to best_model_part_9.hdf5
# Epoch 5/25
# 827/827 [==============================] - 542s 655ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.2743 - val_accuracy: 0.9459
#
# Epoch 00005: saving model to best_model_part_9.hdf5
# Epoch 6/25
# 827/827 [==============================] - 547s 661ms/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 0.2382 - val_accuracy: 0.9493
#
# Epoch 00006: saving model to best_model_part_9.hdf5
# Epoch 7/25
# 827/827 [==============================] - 552s 668ms/step - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.2315 - val_accuracy: 0.9523
#
# Epoch 00007: saving model to best_model_part_9.hdf5
# Epoch 8/25
# 827/827 [==============================] - 607s 734ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 0.2354 - val_accuracy: 0.9489
#
# Epoch 00008: saving model to best_model_part_9.hdf5
# Epoch 9/25
# 827/827 [==============================] - 617s 746ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.2561 - val_accuracy: 0.9502
#
# Epoch 00009: saving model to best_model_part_9.hdf5
# Epoch 10/25
# 827/827 [==============================] - 617s 746ms/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.2690 - val_accuracy: 0.9459
#
# Epoch 00010: saving model to best_model_part_9.hdf5
# Epoch 11/25
# 827/827 [==============================] - 625s 756ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.2115 - val_accuracy: 0.9545
#
# Epoch 00011: saving model to best_model_part_9.hdf5
# Epoch 12/25
# 827/827 [==============================] - 598s 723ms/step - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.2436 - val_accuracy: 0.9528
#
# Epoch 00012: saving model to best_model_part_9.hdf5
# Epoch 13/25
# 827/827 [==============================] - 614s 742ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.2557 - val_accuracy: 0.9515
#
# Epoch 00013: saving model to best_model_part_9.hdf5
# Epoch 14/25
# 827/827 [==============================] - 616s 745ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.2923 - val_accuracy: 0.9442
#
# Epoch 00014: saving model to best_model_part_9.hdf5
# Epoch 15/25
# 827/827 [==============================] - 615s 744ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.2762 - val_accuracy: 0.9485
#
# Epoch 00015: saving model to best_model_part_9.hdf5
# Epoch 16/25
# 827/827 [==============================] - 650s 786ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.2429 - val_accuracy: 0.9541
#
# Epoch 00016: saving model to best_model_part_9.hdf5

# %%
# сохраним итоговую сеть и подгрузим лучшую итерацию в обучении (best_model)
model.save('model_last_{}.hdf5'.format(part))
model.load_weights('best_model_{}.hdf5'.format(part))

# %% [markdown]
# ### Оценим метрику

# %%
scores = model.evaluate_generator(
    test_generator, steps=len(test_generator), verbose=1)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 146/146 [==============================] - 29s 199ms/step - loss: 0.2585 - accuracy: 0.9476
# Accuracy: 94.76%

# %% [markdown]
# ### Step 2: Уменьшим значения аугментации, увеличим размер изображения

# %%
BATCH_SIZE = 4  # уменьшаем batch если сеть большая, иначе не влезет в память на GPU
IMG_SIZE = 512  # какого размера подаем изображения в сеть
IMG_CHANNELS = 3   # у RGB 3 канала
input_shape = (IMG_SIZE, IMG_SIZE, IMG_CHANNELS)
LR=0.00001

# %%
AUGMENTATIONS = albumentations.Compose([
    albumentations.HorizontalFlip(p=0.5),
    albumentations.Rotate(limit=10, interpolation=1, border_mode=4,
                          value=None, mask_value=None, always_apply=False, p=0.8),
    albumentations.Resize(IMG_SIZE, IMG_SIZE)
])

train_datagen = ImageDataAugmentor(
    rescale=1./255,
    augment=AUGMENTATIONS,
    validation_split=VAL_SPLIT,
)

# %%
# Завернем наши данные в генератор:
train_generator = train_datagen.flow_from_directory(
    'data/train/',      # директория где расположены папки с картинками
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, seed=RANDOM_SEED,
    subset='training')  # set as training data

test_generator = train_datagen.flow_from_directory(
    'data/train/',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, seed=RANDOM_SEED,
    subset='validation')  # set as validation data

test_sub_generator = test_datagen.flow_from_dataframe(
    dataframe=sample_submission,
    directory='data/test_upload/',
    x_col="Id",
    y_col=None,
    shuffle=False,
    class_mode=None,
    seed=RANDOM_SEED,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE)
# Out:
# Found 13232 images belonging to 10 classes.
# Found 2329 images belonging to 10 classes.
# Found 6675 validated image filenames.

# %% [markdown]
# Т. к. изменился input_shape, необходимо заново создать сеть

# %%
base_model = Xception(weights='imagenet',
                      include_top=False, input_shape=input_shape)

# %%
# Устанавливаем новую "голову" (head)
x = base_model.output

# x = BatchNormalization()(x)
# x = Dropout(0.2)(x)

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(256, activation='relu')(x)

# x = BatchNormalization()(x)
x = Dropout(0.25)(x)

# and a logistic layer -- let's say we have 10 classes
predictions = Dense(CLASS_NUM, activation='softmax')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(loss="categorical_crossentropy",
              optimizer=optimizers.Adam(lr=LR), metrics=["accuracy"])

# %% [markdown]
# Подгружаем веса

# %%
model.load_weights('best_model_part_9.hdf5')

# %% [markdown]
# Обучаем

# %%
EPOCHS = 15
history = model.fit_generator(
    train_generator,
    steps_per_epoch=len(train_generator),
    validation_data=test_generator,
    validation_steps=len(test_generator),
    epochs=EPOCHS,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/15
# 3308/3308 [==============================] - 3535s 1s/step - loss: 0.4158 - accuracy: 0.8636 - val_loss: 0.1479 - val_accuracy: 0.9588
#
# Epoch 00001: saving model to best_model_part_9.hdf5
# Epoch 2/15
# 3308/3308 [==============================] - 3344s 1s/step - loss: 0.1041 - accuracy: 0.9660 - val_loss: 0.1219 - val_accuracy: 0.9639
#
# Epoch 00002: saving model to best_model_part_9.hdf5
# Epoch 3/15
# 3308/3308 [==============================] - 3356s 1s/step - loss: 0.0782 - accuracy: 0.9753 - val_loss: 0.1213 - val_accuracy: 0.9669
#
# Epoch 00003: saving model to best_model_part_9.hdf5
# Epoch 4/15
# 3308/3308 [==============================] - 3690s 1s/step - loss: 0.0496 - accuracy: 0.9855 - val_loss: 0.1214 - val_accuracy: 0.9695
#
# Epoch 00004: saving model to best_model_part_9.hdf5
# Epoch 5/15
# 3308/3308 [==============================] - 3278s 991ms/step - loss: 0.0359 - accuracy: 0.9891 - val_loss: 0.1267 - val_accuracy: 0.9682
#
# Epoch 00005: saving model to best_model_part_9.hdf5
# Epoch 6/15
# 3308/3308 [==============================] - 3327s 1s/step - loss: 0.0280 - accuracy: 0.9909 - val_loss: 0.1327 - val_accuracy: 0.9699
#
# Epoch 00006: saving model to best_model_part_9.hdf5
# Epoch 7/15
# 3308/3308 [==============================] - 3293s 995ms/step - loss: 0.0201 - accuracy: 0.9945 - val_loss: 0.1353 - val_accuracy: 0.9669
#
# Epoch 00007: saving model to best_model_part_9.hdf5
# Epoch 8/15
# 3308/3308 [==============================] - 3310s 1s/step - loss: 0.0178 - accuracy: 0.9944 - val_loss: 0.1470 - val_accuracy: 0.9644
#
# Epoch 00008: saving model to best_model_part_9.hdf5
# Epoch 9/15
# 3308/3308 [==============================] - 3322s 1s/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.1545 - val_accuracy: 0.9691
#
# Epoch 00009: saving model to best_model_part_9.hdf5
# Epoch 10/15
# 3308/3308 [==============================] - 3377s 1s/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 0.1450 - val_accuracy: 0.9678
#
# Epoch 00010: saving model to best_model_part_9.hdf5
# Epoch 11/15
# 3308/3308 [==============================] - 3525s 1s/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.1821 - val_accuracy: 0.9648
#
# Epoch 00011: saving model to best_model_part_9.hdf5

# %%
# сохраним итоговую сеть и подгрузим лучшую итерацию в обучении (best_model)
model.save('model_last_{}.hdf5'.format(part))
model.load_weights('best_model_{}.hdf5'.format(part))

# %%
# Графики
make_graf(history)

# %% [markdown]
# **Оценим метрику**

# %%
scores = model.evaluate_generator(
    test_generator, steps=len(test_generator), verbose=1)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 583/583 [==============================] - 91s 156ms/step - loss: 0.1490 - accuracy: 0.9695
# Accuracy: 96.95%

# %% [markdown]
# ### Предсказание на тестовых данных

# %%
test_sub_generator.samples
# Out:
# 6675

# %%
test_sub_generator.reset()
predictions = model.predict_generator(
    test_sub_generator, steps=len(test_sub_generator), verbose=1)
predictions = np.argmax(predictions, axis=-1)  # multiple categories
label_map = (train_generator.class_indices)
label_map = dict((v, k) for k, v in label_map.items())  # flip k,v
predictions = [label_map[k] for k in predictions]
# Out:
# 1669/1669 [==============================] - 273s 164ms/step

# %%
filenames_with_dir = test_sub_generator.filenames
submission = pd.DataFrame(
    {'Id': filenames_with_dir, 'Category': predictions}, columns=['Id', 'Category'])
submission['Id'] = submission['Id'].replace('test_upload/', '')
submission.to_csv('submission_{}.csv'.format(part), index=False)
print('Save submit')
# Out:
# Save submit

# %%
submission.head()
# Out:
#            Id Category
# 0  305108.jpg        7
# 1  295075.jpg        6
# 2   31197.jpg        4
# 3   93598.jpg        7
# 4   87877.jpg        7

# %% [markdown]
# ### Step 3: ТТА (Test Time Augmentation)

# %%
AUGMENTATIONS = albumentations.Compose([
    albumentations.HorizontalFlip(p=0.5),
    albumentations.Rotate(limit=10, interpolation=1, border_mode=4,
                          value=None, mask_value=None, always_apply=False, p=0.8),
    albumentations.OneOf([
        albumentations.RandomBrightnessContrast(
            brightness_limit=0.3, contrast_limit=0.3),
        albumentations.RandomBrightnessContrast(
            brightness_limit=0.2, contrast_limit=0.2),
        albumentations.RandomBrightnessContrast(
            brightness_limit=0.1, contrast_limit=0.1)
    ], p=0.7),
    albumentations.Blur(blur_limit=3, always_apply=False, p=0.5),
    albumentations.HueSaturationValue(
        hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, always_apply=False, p=0.7),
    albumentations.RGBShift(r_shift_limit=20, g_shift_limit=20,
                            b_shift_limit=20, always_apply=False, p=0.7),
    albumentations.FancyPCA(alpha=0.1, always_apply=False, p=0.5),
    albumentations.ChannelShuffle(p=0.7),
    albumentations.CLAHE(clip_limit=3.0, tile_grid_size=(
        8, 8), always_apply=False, p=0.3),
    albumentations.Resize(IMG_SIZE, IMG_SIZE)
])

# %% [markdown]
# Работаем с тестовым датасетом

# %%
test_datagen = ImageDataAugmentor( 
    rescale=1./255,
    augment = AUGMENTATIONS,
    validation_split=VAL_SPLIT,
)

# %%
test_sub_generator = test_datagen.flow_from_dataframe(
    dataframe=sample_submission,
    directory='data/test_upload/',
    x_col="Id",
    y_col=None,
    shuffle=False,
    class_mode=None,
    seed=RANDOM_SEED,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE)
# Out:
# Found 6675 validated image filenames.

# %%
tta_steps = 10 # берем среднее из 10 предсказаний
predictions = []

for i in range(tta_steps):
    preds = model.predict_generator(test_sub_generator, steps=len(test_sub_generator), verbose=1) 
    predictions.append(preds)

pred = np.mean(predictions, axis=0)
# Out:
# 1669/1669 [==============================] - 314s 188ms/step
# 1669/1669 [==============================] - 329s 197ms/step
# 1669/1669 [==============================] - 345s 207ms/step
# 1669/1669 [==============================] - 343s 206ms/step
# 1669/1669 [==============================] - 354s 212ms/step
# 1669/1669 [==============================] - 357s 214ms/step
# 1669/1669 [==============================] - 362s 217ms/step
# 1669/1669 [==============================] - 391s 234ms/step
# 1669/1669 [==============================] - 352s 211ms/step
# 1669/1669 [==============================] - 351s 210ms/step

# %%
predictions = np.argmax(pred, axis=-1) #multiple categories
label_map = (train_generator.class_indices)
label_map = dict((v,k) for k,v in label_map.items()) #flip k,v
predictions = [label_map[k] for k in predictions]

# %%
filenames_with_dir=test_sub_generator.filenames
submission = pd.DataFrame({'Id':filenames_with_dir, 'Category':predictions}, columns=['Id', 'Category'])
submission['Id'] = submission['Id'].replace('test_upload/','')
submission.to_csv(f'submission_TTA_{part}.csv', index=False)
print('Save submit')
# Out:
# Save submit

# %% [markdown]
# ### Вывод по данной части работы:
# - Метрика на тесте: 96.95%
# - Метрика на Kaggle: 97.078%
# - Метрика с ТТА: 97.23%
#
# ### Выводы по проекту:
# - Протестировал различные комбинации слоев dropout и batch нормализации.
# - Протестировал различные комбинации полносвязных слоев и количество нейронов в слоях.
# - Протестировал различные параметры аугментации.
# - Протестировал влияние значения learnin rate на качество обучения модели.
# - Применил callbacks функцию для сохранения лучших параметров модели и остановки обучения, когда модель перестает обучаться.
# - Протестировал влияние количества эпох обучения на качество обучения модели.
# - Разобрался с распределением ресурсов ПК между CPU с оперативной памятью и GPU. Существенно улучшил производительность процесса.
# - Протестировал альтернативные имиджнет-модели - FixEfficientNetB7, FixEfficientNetB0.
# - Применил файн тюнинг при обучении модели.
# - Добавил Test Time Augmentation (TTA).
# - Сделал web-сервис, предсказывающий модель авто по загружаемому изображению.
# - Увеличил точность предсказания модели до 97.243%.
